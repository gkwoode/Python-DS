# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Matplotlib Exercises
#
# Welcome to the exercises for reviewing matplotlib! Take your time with these, Matplotlib can be tricky to understand at first. These are relatively simple plots, but they can be hard if this is your first time with matplotlib, feel free to reference the solutions as you go along.
#
# Also don't worry if you find the matplotlib syntax frustrating, we actually won't be using it that often throughout the course, we will switch to using seaborn and pandas built-in visualization capabilities. But, those are built-off of matplotlib, which is why it is still important to get exposure to it!
#
# ** * NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP. * **
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2
# Out:
# StatementMeta(, 4ddd0f12-dc6b-46e2-9791-2837b02c3d7a, 3, Finished, Available, Finished)

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
# Out:
# StatementMeta(, 4ddd0f12-dc6b-46e2-9791-2837b02c3d7a, 4, Finished, Available, Finished)

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, y)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Plot Creation')
# Out:
# StatementMeta(, 4ddd0f12-dc6b-46e2-9791-2837b02c3d7a, 5, Finished, Available, Finished)
# Text(0.5, 1.0, 'Plot Creation')

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])
# Out:
# StatementMeta(, 4ddd0f12-dc6b-46e2-9791-2837b02c3d7a, 6, Finished, Available, Finished)

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
ax1.plot(x, y)
ax2.plot(x, y)

fig
# Out:
# StatementMeta(, 4ddd0f12-dc6b-46e2-9791-2837b02c3d7a, 7, Finished, Available, Finished)

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
y = [1, 0.8, 0.6, 0.4, 0.2, 0.0]
x = np.arange(len(y))

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')

axes[1].set_xlabel('X')
axes[1].set_ylabel('Y')

plt.show()
# Out:
# StatementMeta(, 4ddd0f12-dc6b-46e2-9791-2837b02c3d7a, 8, Finished, Available, Finished)

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
x = np.array([0, 20, 40, 60, 80, 100])
y = np.array([0, 50, 100, 150, 200])
z = np.array([0, 2000, 4000, 6000, 8000, 10000])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(7, 5), sharex=True)

# First plot 
ax1.plot(x[:len(y)], y, color='blue', linewidth=3, linestyle='--', markersize=8)
ax1.set_title('(x, y) Plot')
ax1.set_xlabel('X Values')
ax1.set_ylabel('Y Values')
ax1.set_ylim(0, 200)

# Second plot (x,z)
ax2.plot(x, z, color='red', linewidth=3, linestyle='-', markersize=8)
ax2.set_title('(x, z) Plot')
ax2.set_xlabel('X Values')
ax2.set_ylabel('Z Values')
ax2.set_ylim(0, 10000)

plt.suptitle('Separated Plots of (x,y) and (x,z)', fontsize=14, y=1.05)
plt.tight_layout()
plt.show()
# Out:
# StatementMeta(, 4ddd0f12-dc6b-46e2-9791-2837b02c3d7a, 9, Finished, Available, Finished)

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
x = np.array([0, 20, 40, 60, 80, 100])
y = np.array([0, 50, 100, 150, 200])
z = np.array([0, 2000, 4000, 6000, 8000, 10000])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), sharex=True)

# First plot 
ax1.plot(x[:len(y)], y, color='blue', linewidth=4, linestyle='-', markersize=8)
ax1.set_title('(x, y) Plot')
ax1.set_xlabel('X Values')
ax1.set_ylabel('Y Values')
ax1.set_ylim(0, 200)

# Second plot (x,z)
ax2.plot(x[:len(z)], z, color='red', linewidth=3, linestyle='--', markersize=8)
ax2.set_title('(x, z) Plot')
ax2.set_xlabel('X Values')
ax2.set_ylabel('Z Values')
ax2.set_ylim(0, 10000)

# Main title and layout adjustment
plt.suptitle('Separated Plots of (x,y) and (x,z)', fontsize=14, y=1.05)
plt.tight_layout()
plt.show()
# Out:
# StatementMeta(, 4ddd0f12-dc6b-46e2-9791-2837b02c3d7a, 10, Finished, Available, Finished)

# %% [markdown]
# # Great Job!
