# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Pandas Data Visualization Exercise
#
# This is just a quick exercise for you to review the various plots we showed earlier. Use **df3** to replicate the following plots.

# %%
# Import the libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# StatementMeta(, 7cb16139-9a66-46a0-a157-8630a8421548, 3, Finished, Available, Finished)

# %%
# Load data into pandas DataFrame from f"{notebookutils.nbResPath}/builtin/df3.txt"
df3 =  pd.read_csv(f"{notebookutils.nbResPath}/builtin/df3.txt")
# Out:
# StatementMeta(, 7cb16139-9a66-46a0-a157-8630a8421548, 4, Finished, Available, Finished)

# %%
df3.info()
# Out:
# StatementMeta(, 7cb16139-9a66-46a0-a157-8630a8421548, 5, Finished, Available, Finished)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
# StatementMeta(, 7cb16139-9a66-46a0-a157-8630a8421548, 6, Finished, Available, Finished)
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# ** Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion. Remeber back to your matplotlib lecture...**

# %%
plt.figure(figsize=(8, 4))

plt.scatter(df3['a'], df3['b'], color='red')

plt.xlim(-0.2, 1.2)
plt.ylim(-0.2, 1.2)
plt.xlabel('a')
plt.ylabel('b')

plt.tight_layout()

plt.show()
# Out:
# StatementMeta(, 7cb16139-9a66-46a0-a157-8630a8421548, 7, Finished, Available, Finished)

# %% [markdown]
# ** Create a histogram of the 'a' column.**

# %%
plt.figure(figsize=(8, 6))
plt.hist(df3['a'], bins=15, color='blue', edgecolor='black')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.xlim(0.0, 1.0)

plt.tight_layout()
plt.show()
# Out:
# StatementMeta(, 7cb16139-9a66-46a0-a157-8630a8421548, 8, Finished, Available, Finished)

# %% [markdown]
# ** These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
plt.style.use('ggplot')

plt.figure(figsize=(10, 6))

n, bins, patches = plt.hist(df3['a'], bins=15, color='#4C72B0', edgecolor='white', linewidth=1.2, alpha=0.9)

plt.title('Distribution of Column "a" Values', 
          fontsize=14, pad=20)
plt.xlabel('Value Bins', fontsize=12, labelpad=10)
plt.ylabel('Frequency', fontsize=12, labelpad=10)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True, alpha=0.3)

for i in range(len(patches)):
    plt.text(patches[i].get_x() + patches[i].get_width()/2, 
             patches[i].get_height()+0.5, 
             str(int(n[i])),
             ha='center',
             fontsize=9)

plt.xlim(0, 1.0)
plt.ylim(0, max(n)+1)
plt.tight_layout()

plt.show()
# Out:
# StatementMeta(, 7cb16139-9a66-46a0-a157-8630a8421548, 9, Finished, Available, Finished)

# %% [markdown]
# ** Create a boxplot comparing the a and b columns.**

# %%
plt.style.use('ggplot')

plt.figure(figsize=(6, 4))

bp = plt.boxplot([df3['a'], df3['b']], 
                 patch_artist=True,
                 labels=['a', 'b'],
                 widths=0.6,
                 showmeans=True,
                 meanprops={'marker':'D', 
                           'markerfacecolor':'white', 
                           'markeredgecolor':'black'})

colors = ['#6E72D0', '#F48CC2']
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.8)

plt.setp(bp['whiskers'], color='gray', linestyle='-')
plt.setp(bp['medians'], color='black', linewidth=1.5)

plt.title('Comparison of Columns a and b', fontsize=14, pad=15)
plt.ylabel('Values', fontsize=12, labelpad=10)

plt.tight_layout()

plt.show()
# Out:
# StatementMeta(, 7cb16139-9a66-46a0-a157-8630a8421548, 10, Finished, Available, Finished)

# %% [markdown]
# ** Create a kde plot of the 'd' column **

# %%
plt.style.use('ggplot')

plt.figure(figsize=(6, 4), dpi=100)

sns.kdeplot(data=df3, x='d', 
            color='#FFB22C',
            linewidth=1.5,
            fill=True,
            alpha=0.25,
            edgecolor='black')

plt.title('Density Distribution of Column d Values', fontsize=14, pad=15)
plt.xlabel('Value', fontsize=12, labelpad=10)
plt.ylabel('Density', fontsize=12, labelpad=10)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True, alpha=0.3)

mean_val = df3['d'].mean()
plt.axvline(mean_val, color='#169976', linestyle='--', linewidth=1.5)
plt.text(mean_val+0.05, plt.ylim()[1]*0.9, 
         f'Mean: {mean_val:.2f}', 
         color='#169976',
         fontsize=11)

plt.tight_layout()
plt.show()
# Out:
# StatementMeta(, 7cb16139-9a66-46a0-a157-8630a8421548, 11, Finished, Available, Finished)
# /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ** Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line)**

# %%
plt.style.use('ggplot')

plt.figure(figsize=(6, 4))

sns.kdeplot(data=df3, x='d',
            color='#55A868',
            linewidth=3.5,
            linestyle='--',
            fill=False,
            alpha=0.8)

plt.title('Modified KDE Plot of Column d', fontsize=14, pad=15)
plt.xlabel('Value', fontsize=12, labelpad=10)
plt.ylabel('Density', fontsize=12, labelpad=10)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True, alpha=0.3)

mean_val = df3['d'].mean()
plt.axvline(mean_val, color='#0118D8', linestyle='-', linewidth=1)
plt.text(mean_val+0.05, plt.ylim()[1]*0.9,
         f'Mean: {mean_val:.2f}',
         color='#0118D8',
         fontsize=11)

plt.tight_layout()
plt.show()
# Out:
# StatementMeta(, 7cb16139-9a66-46a0-a157-8630a8421548, 12, Finished, Available, Finished)
# /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ** Create an area plot of all the columns for just the rows up to 30. (hint: use .ix).**

# %%
plt.style.use('ggplot')

plot_data = df3.loc[:30]

plt.figure(figsize=(8, 6))
plt.stackplot(range(len(plot_data)), 
             plot_data['a'], plot_data['b'], 
             plot_data['c'], plot_data['d'],
             labels=['a', 'b', 'c', 'd'],
             colors=['#410445', '#A5158C', '#205781', '#F6DC43'],
             alpha=0.8)

plt.title('Area Plot of Columns a-d', fontsize=14, pad=15)
plt.xlabel('Row Index', fontsize=12, labelpad=10)
plt.ylabel('Values', fontsize=12, labelpad=10)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True, alpha=0.3)
plt.legend(loc='upper right', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# StatementMeta(, 7cb16139-9a66-46a0-a157-8630a8421548, 13, Finished, Available, Finished)

# %% [markdown]
# ## Bonus Challenge!
# Note, you may find this really hard, reference the solutions if you can't figure it out!
# ** Notice how the legend in our previous figure overlapped some of actual diagram. Can you figure out how to display the legend outside of the plot as shown below?**
#
# ** Try searching Google for a good stackoverflow link on this topic. If you can't find it on your own - [use this one for a hint.](http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas)**

# %%
plt.style.use('ggplot')

plt.figure(figsize=(12, 6))

stack = plt.stackplot(range(len(plot_data)), 
                     plot_data['a'], plot_data['b'], 
                     plot_data['c'], plot_data['d'],
                     labels=['a', 'b', 'c', 'd'],
                     colors=['#410445', '#A5158C', '#205781', '#F6DC43'],
                     alpha=0.8)

plt.title('Area Plot of Columns a-d with External Legend', fontsize=14, pad=15)
plt.xlabel('Row Index', fontsize=12, labelpad=10)
plt.ylabel('Values', fontsize=12, labelpad=10)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True, alpha=0.3)

plt.legend(bbox_to_anchor=(1.02, 1),
           loc='upper left', 
           borderaxespad=0.,
           fontsize=10,
           frameon=True)

plt.tight_layout(rect=[0, 0, 0.85, 1])

plt.show()
# Out:
# StatementMeta(, 7cb16139-9a66-46a0-a157-8630a8421548, 14, Finished, Available, Finished)

# %% [markdown]
# # Great Job!
